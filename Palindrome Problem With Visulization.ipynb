# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

'''
The function below is trying to solve a math problem that asks: For any number if you add its inverse a certian amount 
of times, it will eventually become a palindrome, True or False? For example, 23 + its inverse, 32 = 55. 
Numbers that are already palindromes like 3, or 77 don't go through this process.


There are 2 inputs that you need to provide:
1. The amount of numbers you want to examine.
2. The maximum number of times that each number goes through the adding its inverse process.
'''
def palindrome_conjecture(): 
    y = int(input("what would you like your range of numbers to be?:"))
    x = int(input("what would you like your counter range to be?:"))
    step_counter = 0 #counts the amount of steps each number takes before becoming a palindrome
    non_palindrome_counter = 0 #counts the amount of numbers that take more than your input steps to become a palindrome
    counter_array = np.zeros(x,dtype = int) #sets up a list with your input 0's so it can become a counter later
    plt_array = np.zeros(y,dtype = int)
    number_of_steps = np.zeros(y,dtype = int)
    y_dividedby_10 = y/10
    for num in range(y): #for numbers in the input that is given
        str_num = str(num)         
        while not int(str_num) == int(str_num[::-1]) and not step_counter > x: # while its not a palindrome and the
            #step counter is less than your input
            
            str_num = str(int(str_num)+int(str_num[::-1])) #number is added to its inverse
            step_counter = step_counter + 1 #another step is added to the amount of steps
        
        if step_counter > x: #if the amount of steps is bigger than your input
            print(num, "takes more than",x,"steps to become a palindrome")# print out the number and that it takes more steps
            non_palindrome_counter +=1 #another number does not become a palindrome in less than your input
            step_counter = 0 #step counter restets
            
            
        
        else: #if the number becomes a palindrome in less than your input
            print(num,"becomes a palindrome in",step_counter,"steps") #print the number and how many steps it takes
            counter_array[step_counter] +=1 # the amount of numbers that take that amount of steps, goes up by 1
            plt_array[num] = step_counter
        step_counter = 0 #step counter restets
    print('\n')
    print('\n')
    for i in range(len(counter_array)): # for number in the length of the counter list
             if not counter_array[i] == 0:
                print("There are",counter_array[i],"numbers that take",i,"steps") #print out the amount of numbers there are that take each amount of steps
                number_of_steps[i] = i
    print("There are",non_palindrome_counter,"numbers, less than",y, "that take more than",x,"steps to become a palindrome") #print out the aount of numbers that don't become a palindrome
    
    # The visulization
    plt.hist(plt_array,color='blue',density=True)
    plt.margins(.000001)
    plt.title('Palindrome Visulization')
    plt.ylim(.1)
    plt.xlabel('number of steps')
    plt.ylabel('amount of numbers')
    plt.xticks(np.arange(number_of_steps.max()+2,step=2))
    plt.yticks(np.arange(1,step=.1))
    
palindrome_conjecture()
# Out:
# what would you like your range of numbers to be?:100
# what would you like your counter range to be?:100
# 0 becomes a palindrome in 0 steps
# 1 becomes a palindrome in 0 steps
# 2 becomes a palindrome in 0 steps
# 3 becomes a palindrome in 0 steps
# 4 becomes a palindrome in 0 steps
# 5 becomes a palindrome in 0 steps
# 6 becomes a palindrome in 0 steps
# 7 becomes a palindrome in 0 steps
# 8 becomes a palindrome in 0 steps
# 9 becomes a palindrome in 0 steps
# 10 becomes a palindrome in 1 steps
# 11 becomes a palindrome in 0 steps
# 12 becomes a palindrome in 1 steps
# 13 becomes a palindrome in 1 steps
# 14 becomes a palindrome in 1 steps
# 15 becomes a palindrome in 1 steps
# 16 becomes a palindrome in 1 steps
# 17 becomes a palindrome in 1 steps
# 18 becomes a palindrome in 1 steps
# 19 becomes a palindrome in 2 steps
# 20 becomes a palindrome in 1 steps
# 21 becomes a palindrome in 1 steps
# 22 becomes a palindrome in 0 steps
# 23 becomes a palindrome in 1 steps
# 24 becomes a palindrome in 1 steps
# 25 becomes a palindrome in 1 steps
# 26 becomes a palindrome in 1 steps
# 27 becomes a palindrome in 1 steps
# 28 becomes a palindrome in 2 steps
# 29 becomes a palindrome in 1 steps
# 30 becomes a palindrome in 1 steps
# 31 becomes a palindrome in 1 steps
# 32 becomes a palindrome in 1 steps
# 33 becomes a palindrome in 0 steps
# 34 becomes a palindrome in 1 steps
# 35 becomes a palindrome in 1 steps
# 36 becomes a palindrome in 1 steps
# 37 becomes a palindrome in 2 steps
# 38 becomes a palindrome in 1 steps
# 39 becomes a palindrome in 2 steps
# 40 becomes a palindrome in 1 steps
# 41 becomes a palindrome in 1 steps
# 42 becomes a palindrome in 1 steps
# 43 becomes a palindrome in 1 steps
# 44 becomes a palindrome in 0 steps
# 45 becomes a palindrome in 1 steps
# 46 becomes a palindrome in 2 steps
# 47 becomes a palindrome in 1 steps
# 48 becomes a palindrome in 2 steps
# 49 becomes a palindrome in 2 steps
# 50 becomes a palindrome in 1 steps
# 51 becomes a palindrome in 1 steps
# 52 becomes a palindrome in 1 steps
# 53 becomes a palindrome in 1 steps
# 54 becomes a palindrome in 1 steps
# 55 becomes a palindrome in 0 steps
# 56 becomes a palindrome in 1 steps
# 57 becomes a palindrome in 2 steps
# 58 becomes a palindrome in 2 steps
# 59 becomes a palindrome in 3 steps
# 60 becomes a palindrome in 1 steps
# 61 becomes a palindrome in 1 steps
# 62 becomes a palindrome in 1 steps
# 63 becomes a palindrome in 1 steps
# 64 becomes a palindrome in 2 steps
# 65 becomes a palindrome in 1 steps
# 66 becomes a palindrome in 0 steps
# 67 becomes a palindrome in 2 steps
# 68 becomes a palindrome in 3 steps
# 69 becomes a palindrome in 4 steps
# 70 becomes a palindrome in 1 steps
# 71 becomes a palindrome in 1 steps
# 72 becomes a palindrome in 1 steps
# 73 becomes a palindrome in 2 steps
# 74 becomes a palindrome in 1 steps
# 75 becomes a palindrome in 2 steps
# 76 becomes a palindrome in 2 steps
# 77 becomes a palindrome in 0 steps
# 78 becomes a palindrome in 4 steps
# 79 becomes a palindrome in 6 steps
# 80 becomes a palindrome in 1 steps
# 81 becomes a palindrome in 1 steps
# 82 becomes a palindrome in 2 steps
# 83 becomes a palindrome in 1 steps
# 84 becomes a palindrome in 2 steps
# 85 becomes a palindrome in 2 steps
# 86 becomes a palindrome in 3 steps
# 87 becomes a palindrome in 4 steps
# 88 becomes a palindrome in 0 steps
# 89 becomes a palindrome in 24 steps
# 90 becomes a palindrome in 1 steps
# 91 becomes a palindrome in 2 steps
# 92 becomes a palindrome in 1 steps
# 93 becomes a palindrome in 2 steps
# 94 becomes a palindrome in 2 steps
# 95 becomes a palindrome in 3 steps
# 96 becomes a palindrome in 4 steps
# 97 becomes a palindrome in 6 steps
# 98 becomes a palindrome in 24 steps
# 99 becomes a palindrome in 0 steps
#
#
#
#
# There are 19 numbers that take 0 steps
# There are 49 numbers that take 1 steps
# There are 20 numbers that take 2 steps
# There are 4 numbers that take 3 steps
# There are 4 numbers that take 4 steps
# There are 2 numbers that take 6 steps
# There are 2 numbers that take 24 steps
# There are 0 numbers, less than 100 that take more than 100 steps to become a palindrome
